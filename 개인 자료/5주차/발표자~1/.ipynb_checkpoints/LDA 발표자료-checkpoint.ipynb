# %% [markdown]
# ### LDA

# %% [markdown]
# 클래스 간의 차별성을 최대화 할 수 있는 방향으로 차원을 축소하고 싶을 때 사용한다. 아래 그림을 보면, 어떤 것의 구별성이 가장 좋은가?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# __분리될 class간의 각각의 평균 거리는 멀수록 좋다.__
# __각 class안에서의 분산은 작을 수록 좋다.__

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
